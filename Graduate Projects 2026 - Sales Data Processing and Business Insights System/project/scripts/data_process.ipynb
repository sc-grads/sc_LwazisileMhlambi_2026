# %%
#Importing pandas to clean data
import pandas as pd
import logging as lg

# %%
lg.basicConfig(filename="C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/data_cleaning_log.csv",
               level=lg.INFO,
               format='%(asctime)s %(levelname)s - %(message)s'
               )

# %%
lg.info("Loading the Uncleaned Dataset")
df = pd.read_csv(r"C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/data/Messy_Sales_data.csv")
df.head()
# Out:
#    transaction_id        date product     category  quantity  price region  \
# 0            1001  2024-01-05  Laptop  Electronics       2.0  12000  North
# 1            1002  2024-01-07   Phone  Electronics       5.0   8000  South
# 2            1003  2024-01-10  Tablet  Electronics       3.0   6000   East
# 3            1003  2024-01-10  Tablet  Electronics       3.0   6000   East
# 4            1004  2024-01-15   Chair    Furniture       NaN   1500   West
#
#   salesperson
# 0        John
# 1        Mary
# 2       David
# 3       David
# 4       Sarah

# %%
#Viewing the different data types in the document
#The end result is that date is in string form and needs to be changed into dateformat
#The price needs to be changed into a currency (round off to 2 decimal places)
#The quantity being a float, has to change back into an integer
lg.info("Viewing the different data types in the document")
df.dtypes
# Out:
# transaction_id      int64
# date                  str
# product               str
# category              str
# quantity          float64
# price               int64
# region                str
# salesperson           str
# dtype: object

# %%
#Converting date string to time
lg.info("Changing date datatype from string to datetime")
df['date'] = pd.to_datetime(df['date'], format="%Y-%m-%d")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  52 non-null     int64
#  1   date            52 non-null     datetime64[us]
#  2   product         52 non-null     str
#  3   category        52 non-null     str
#  4   quantity        50 non-null     float64
#  5   price           52 non-null     int64
#  6   region          52 non-null     str
#  7   salesperson     50 non-null     str
# dtypes: datetime64[us](1), float64(1), int64(2), str(4)
# memory usage: 3.4 KB

# %%
lg.info("Changing from integer to float (decimal)")
df['price'] = df['price'].astype(float)
df.head()
# Out:
#    transaction_id       date product     category  quantity    price region  \
# 0            1001 2024-01-05  Laptop  Electronics       2.0  12000.0  North
# 1            1002 2024-01-07   Phone  Electronics       5.0   8000.0  South
# 2            1003 2024-01-10  Tablet  Electronics       3.0   6000.0   East
# 3            1003 2024-01-10  Tablet  Electronics       3.0   6000.0   East
# 4            1004 2024-01-15   Chair    Furniture       NaN   1500.0   West
#
#   salesperson
# 0        John
# 1        Mary
# 2       David
# 3       David
# 4       Sarah

# %%
#Rechecking data types
lg.info("Rechecking data types")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  52 non-null     int64
#  1   date            52 non-null     datetime64[us]
#  2   product         52 non-null     str
#  3   category        52 non-null     str
#  4   quantity        50 non-null     float64
#  5   price           52 non-null     float64
#  6   region          52 non-null     str
#  7   salesperson     50 non-null     str
# dtypes: datetime64[us](1), float64(2), int64(1), str(4)
# memory usage: 3.4 KB

# %%
#Looking for duplicates
lg.info("Looking for duplicates")
#We have 2 duplicates in the dataset
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
#Dropping duplicated entries
lg.info("Dropping duplicated entries")
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Counting for empty rows in the dataframe
lg.info("Counting for empty rows in the dataframe")
#Result is 2 empty rows in quantity and 2 in salesperson
df.isna().sum()
# Out:
# transaction_id    0
# date              0
# product           0
# category          0
# quantity          2
# price             0
# region            0
# salesperson       2
# dtype: int64

# %%
#Showcasing specific empty rows
lg.info("Showcasing specific empty rows")
df[df.isna().any(axis=1)]
# Out:
#     transaction_id       date product     category  quantity    price region  \
# 4             1004 2024-01-15   Chair    Furniture       NaN   1500.0   West
# 10            1010 2024-02-03    Desk    Furniture       3.0   3000.0  South
# 45            1044 2024-04-18   Chair    Furniture       NaN   1500.0   West
# 47            1046 2024-04-22  Laptop  Electronics       1.0  12000.0  South
#
#    salesperson
# 4        Sarah
# 10         NaN
# 45       Sarah
# 47         NaN

# %%
#Filling in the empty salesperson rows
lg.info("Filling in the empty salesperson rows")
df['salesperson'] = df.groupby('region')['salesperson'].transform(lambda x: x.fillna(x.mode()[0]))
df.isna().sum()
# Out:
# transaction_id    0
# date              0
# product           0
# category          0
# quantity          2
# price             0
# region            0
# salesperson       0
# dtype: int64

# %%
#Calculating the average number of chairs
lg.info("Calculating the average number of chairs")
avg_chairs = df[df['product'] == 'Chair']['quantity'].mean()
avg_chairs.round(0)
lg.info("Filling in the empty chair values")
#Filling in the empty chair values
df.fillna({'quantity': avg_chairs.round(0)}, inplace=True)
df.isna().sum()
# Out:
# transaction_id    0
# date              0
# product           0
# category          0
# quantity          0
# price             0
# region            0
# salesperson       0
# dtype: int64

# %%
df
# Out:
#     transaction_id       date product     category  quantity    price region  \
# 0             1001 2024-01-05  Laptop  Electronics       2.0  12000.0  North
# 1             1002 2024-01-07   Phone  Electronics       5.0   8000.0  South
# 2             1003 2024-01-10  Tablet  Electronics       3.0   6000.0   East
# 4             1004 2024-01-15   Chair    Furniture       5.0   1500.0   West
# 5             1005 2024-01-20    Desk    Furniture       2.0   3000.0  North
# 6             1006 2024-01-22  Laptop  Electronics       1.0  12000.0  South
# 7             1007 2024-01-25   Phone  Electronics       6.0   8000.0   East
# 8             1008 2024-01-28  Tablet  Electronics       2.0   6000.0   West
# 9             1009 2024-02-01   Chair    Furniture       5.0   1500.0  North
# 10            1010 2024-02-03    Desk    Furniture       3.0   3000.0  South
# 11            1011 2024-02-05  Laptop  Electronics       2.0  12000.0   East
# 12            1012 2024-02-07   Phone  Electronics       4.0   8000.0   West
# 13            1013 2024-02-10  Tablet  Electronics       3.0   6000.0  North
# 14            1014 2024-02-12   Chair    Furniture       6.0   1500.0  South
# 15            1015 2024-02-15    Desk    Furniture       2.0   3000.0   East
# 16            1016 2024-02-18  Laptop  Electronics       1.0  12000.0   West
# 17            1017 2024-02-20   Phone  Electronics       7.0   8000.0  North
# 18            1018 2024-02-22  Tablet  Electronics       2.0   6000.0  South
# 19            1019 2024-02-25   Chair    Furniture       4.0   1500.0   East
# 20            1020 2024-02-28    Desk    Furniture       3.0   3000.0   West
# 21            1021 2024-03-02  Laptop  Electronics       2.0  12000.0  North
# 22            1022 2024-03-04   Phone  Electronics       5.0   8000.0  South
# 23            1023 2024-03-06  Tablet  Electronics       3.0   6000.0   East
# 24            1024 2024-03-08   Chair    Furniture       4.0   1500.0   West
# 25            1025 2024-03-10    Desk    Furniture       2.0   3000.0  North
# 26            1026 2024-03-12  Laptop  Electronics       1.0  12000.0  South
# 27            1027 2024-03-14   Phone  Electronics       6.0   8000.0   East
# 28            1028 2024-03-16  Tablet  Electronics       2.0   6000.0   West
# 29            1029 2024-03-18   Chair    Furniture       5.0   1500.0  North
# 30            1030 2024-03-20    Desk    Furniture       3.0   3000.0  South
# 32            1031 2024-03-22  Laptop  Electronics       2.0  12000.0   East
# 33            1032 2024-03-24   Phone  Electronics       4.0   8000.0   West
# 34            1033 2024-03-26  Tablet  Electronics       3.0   6000.0  North
# 35            1034 2024-03-28   Chair    Furniture       6.0   1500.0  South
# 36            1035 2024-03-30    Desk    Furniture       2.0   3000.0   East
# 37            1036 2024-04-02  Laptop  Electronics       1.0  12000.0   West
# 38            1037 2024-04-04   Phone  Electronics       7.0   8000.0  North
# 39            1038 2024-04-06  Tablet  Electronics       2.0   6000.0  South
# 40            1039 2024-04-08   Chair    Furniture       4.0   1500.0   East
# 41            1040 2024-04-10    Desk    Furniture       3.0   3000.0   West
# 42            1041 2024-04-12  Laptop  Electronics       2.0  12000.0  North
# 43            1042 2024-04-14   Phone  Electronics       5.0   8000.0  South
# 44            1043 2024-04-16  Tablet  Electronics       3.0   6000.0   East
# 45            1044 2024-04-18   Chair    Furniture       5.0   1500.0   West
# 46            1045 2024-04-20    Desk    Furniture       2.0   3000.0  North
# 47            1046 2024-04-22  Laptop  Electronics       1.0  12000.0  South
# 48            1047 2024-04-24   Phone  Electronics       6.0   8000.0   East
# 49            1048 2024-04-26  Tablet  Electronics       2.0   6000.0   West
# 50            1049 2024-04-28   Chair    Furniture       5.0   1500.0  North
# 51            1050 2024-04-30    Desk    Furniture       3.0   3000.0  South
#
#    salesperson
# 0         John
# 1         Mary
# 2        David
# 4        Sarah
# 5         John
# 6         Mary
# 7        David
# 8        Sarah
# 9         John
# 10        Mary
# 11       David
# 12       Sarah
# 13        John
# 14        Mary
# 15       David
# 16       Sarah
# 17        John
# 18        Mary
# 19       David
# 20       Sarah
# 21        John
# 22        Mary
# 23       David
# 24       Sarah
# 25        John
# 26        Mary
# 27       David
# 28       Sarah
# 29        John
# 30        Mary
# 32       David
# 33       Sarah
# 34        John
# 35        Mary
# 36       David
# 37       Sarah
# 38        John
# 39        Mary
# 40       David
# 41       Sarah
# 42        John
# 43        Mary
# 44       David
# 45       Sarah
# 46        John
# 47        Mary
# 48       David
# 49       Sarah
# 50        John
# 51        Mary

# %%
#Resetting the index
lg.info("Resetting the index")
df =df.reset_index(drop=True)
df.head()
# Out:
#    transaction_id       date product     category  quantity    price region  \
# 0            1001 2024-01-05  Laptop  Electronics       2.0  12000.0  North
# 1            1002 2024-01-07   Phone  Electronics       5.0   8000.0  South
# 2            1003 2024-01-10  Tablet  Electronics       3.0   6000.0   East
# 3            1004 2024-01-15   Chair    Furniture       5.0   1500.0   West
# 4            1005 2024-01-20    Desk    Furniture       2.0   3000.0  North
#
#   salesperson
# 0        John
# 1        Mary
# 2       David
# 3       Sarah
# 4        John

# %%
#Inserting revenue column
lg.info("Inserting revenue column")
df['revenue'] = df['quantity'] * df['price']
df.head()
# Out:
#    transaction_id       date product     category  quantity    price region  \
# 0            1001 2024-01-05  Laptop  Electronics       2.0  12000.0  North
# 1            1002 2024-01-07   Phone  Electronics       5.0   8000.0  South
# 2            1003 2024-01-10  Tablet  Electronics       3.0   6000.0   East
# 3            1004 2024-01-15   Chair    Furniture       5.0   1500.0   West
# 4            1005 2024-01-20    Desk    Furniture       2.0   3000.0  North
#
#   salesperson  revenue
# 0        John  24000.0
# 1        Mary  40000.0
# 2       David  18000.0
# 3       Sarah   7500.0
# 4        John   6000.0

# %%
#Adding month column
lg.info("Adding month column")
df['month'] = df['date'].dt.month_name()
df.head()
# Out:
#    transaction_id       date product     category  quantity    price region  \
# 0            1001 2024-01-05  Laptop  Electronics       2.0  12000.0  North
# 1            1002 2024-01-07   Phone  Electronics       5.0   8000.0  South
# 2            1003 2024-01-10  Tablet  Electronics       3.0   6000.0   East
# 3            1004 2024-01-15   Chair    Furniture       5.0   1500.0   West
# 4            1005 2024-01-20    Desk    Furniture       2.0   3000.0  North
#
#   salesperson  revenue    month
# 0        John  24000.0  January
# 1        Mary  40000.0  January
# 2       David  18000.0  January
# 3       Sarah   7500.0  January
# 4        John   6000.0  January

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  50 non-null     int64
#  1   date            50 non-null     datetime64[us]
#  2   product         50 non-null     str
#  3   category        50 non-null     str
#  4   quantity        50 non-null     float64
#  5   price           50 non-null     float64
#  6   region          50 non-null     str
#  7   salesperson     50 non-null     str
#  8   revenue         50 non-null     float64
#  9   month           50 non-null     str
# dtypes: datetime64[us](1), float64(3), int64(1), str(5)
# memory usage: 4.0 KB

# %%
lg.info("Exporting Cleaned Dataset")
lg.info("Data Cleaning Complete")
df.to_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/clean_sales.csv", index=False)

# %%
#Sales by Region
lg.info("Reading Cleaned Data for Sales by Region Aggregation")
sbr = pd.read_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/clean_sales.csv")
sbr.tail()
# Out:
#     transaction_id        date product     category  quantity    price region  \
# 45            1046  2024-04-22  Laptop  Electronics       1.0  12000.0  South
# 46            1047  2024-04-24   Phone  Electronics       6.0   8000.0   East
# 47            1048  2024-04-26  Tablet  Electronics       2.0   6000.0   West
# 48            1049  2024-04-28   Chair    Furniture       5.0   1500.0  North
# 49            1050  2024-04-30    Desk    Furniture       3.0   3000.0  South
#
#    salesperson  revenue  month
# 45        Mary  12000.0  April
# 46       David  48000.0  April
# 47       Sarah  12000.0  April
# 48        John   7500.0  April
# 49        Mary   9000.0  April

# %%
lg.info("Aggregating Sales by Region")
sbr = sbr.groupby('region').agg(
    total_sales_revenue = ('revenue', 'sum'),
    total_quantity_sold = ('quantity', 'sum'),
    total_number_of_orders = ('transaction_id', 'count'),
    average_sales_revenue = ('revenue', 'mean')).round(2).reset_index()

# %%
sbr
# Out:
#   region  total_sales_revenue  total_quantity_sold  total_number_of_orders  \
# 0   East             270000.0                 43.0                      12
# 1  North             260500.0                 47.0                      13
# 2  South             225000.0                 43.0                      13
# 3   West             163000.0                 36.0                      12
#
#    average_sales_revenue
# 0               22500.00
# 1               20038.46
# 2               17307.69
# 3               13583.33

# %%
lg.info("Saving to sales_by_region.csv")
sbr.to_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/sales_by_region.csv", index=False)

# %%
#Sales by Product
lg.info("Reading Cleaned Data for Sales by Product Aggregation")
sbp = pd.read_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/clean_sales.csv")
sbp.tail()
# Out:
#     transaction_id        date product     category  quantity    price region  \
# 45            1046  2024-04-22  Laptop  Electronics       1.0  12000.0  South
# 46            1047  2024-04-24   Phone  Electronics       6.0   8000.0   East
# 47            1048  2024-04-26  Tablet  Electronics       2.0   6000.0   West
# 48            1049  2024-04-28   Chair    Furniture       5.0   1500.0  North
# 49            1050  2024-04-30    Desk    Furniture       3.0   3000.0  South
#
#    salesperson  revenue  month
# 45        Mary  12000.0  April
# 46       David  48000.0  April
# 47       Sarah  12000.0  April
# 48        John   7500.0  April
# 49        Mary   9000.0  April

# %%
lg.info("Aggregating Sales by Product")
sbp = sbp.groupby('product').agg(
    total_sales_revenue = ('revenue', 'sum'),
    total_quantity_sold = ('quantity', 'sum'),
    total_number_of_orders = ('transaction_id', 'count'),
    average_sales_revenue = ('revenue', 'mean')).round(2).reset_index()

# %%
sbp
# Out:
#   product  total_sales_revenue  total_quantity_sold  total_number_of_orders  \
# 0   Chair              73500.0                 49.0                      10
# 1    Desk              75000.0                 25.0                      10
# 2  Laptop             180000.0                 15.0                      10
# 3   Phone             440000.0                 55.0                      10
# 4  Tablet             150000.0                 25.0                      10
#
#    average_sales_revenue
# 0                 7350.0
# 1                 7500.0
# 2                18000.0
# 3                44000.0
# 4                15000.0

# %%
lg.info("Saving to sales_by_product.csv")
sbp.to_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/sales_by_product.csv", index=False)

# %%
#Monthly Revenue
lg.info("Reading Cleaned Data for Monthly Revenue Aggregation")
mr = pd.read_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/clean_sales.csv")
mr.tail()
# Out:
#     transaction_id        date product     category  quantity    price region  \
# 45            1046  2024-04-22  Laptop  Electronics       1.0  12000.0  South
# 46            1047  2024-04-24   Phone  Electronics       6.0   8000.0   East
# 47            1048  2024-04-26  Tablet  Electronics       2.0   6000.0   West
# 48            1049  2024-04-28   Chair    Furniture       5.0   1500.0  North
# 49            1050  2024-04-30    Desk    Furniture       3.0   3000.0  South
#
#    salesperson  revenue  month
# 45        Mary  12000.0  April
# 46       David  48000.0  April
# 47       Sarah  12000.0  April
# 48        John   7500.0  April
# 49        Mary   9000.0  April

# %%
lg.info("Aggregating Monthly Revenue")
mr = mr.groupby('month').agg(
    total_sales_revenue = ('revenue', 'sum'),
    total_quantity_sold = ('quantity', 'sum'),
    total_number_of_orders = ('transaction_id', 'count'),
    average_sales_revenue = ('revenue', 'mean')).round(2).reset_index()

# %%
mr
# Out:
#       month  total_sales_revenue  total_quantity_sold  total_number_of_orders  \
# 0     April             279000.0                 51.0                      15
# 1  February             200500.0                 42.0                      12
# 2   January             167500.0                 26.0                       8
# 3     March             271500.0                 50.0                      15
#
#    average_sales_revenue
# 0               18600.00
# 1               16708.33
# 2               20937.50
# 3               18100.00

# %%
lg.info("Saving to monthly_revenue.csv")
mr.to_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/monthly_revenue.csv", index=False)

# %%
#Sales Person Performance
lg.info("Reading Cleaned Data for Salesperson Performance Aggregation")
spp = pd.read_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/clean_sales.csv")
spp.tail()
# Out:
#     transaction_id        date product     category  quantity    price region  \
# 45            1046  2024-04-22  Laptop  Electronics       1.0  12000.0  South
# 46            1047  2024-04-24   Phone  Electronics       6.0   8000.0   East
# 47            1048  2024-04-26  Tablet  Electronics       2.0   6000.0   West
# 48            1049  2024-04-28   Chair    Furniture       5.0   1500.0  North
# 49            1050  2024-04-30    Desk    Furniture       3.0   3000.0  South
#
#    salesperson  revenue  month
# 45        Mary  12000.0  April
# 46       David  48000.0  April
# 47       Sarah  12000.0  April
# 48        John   7500.0  April
# 49        Mary   9000.0  April

# %%
lg.info("Aggregating Salesperson Performance")
spp = spp.groupby(['salesperson', 'product']).agg(
    total_sales_revenue = ('revenue', 'sum'),
    total_quantity_sold = ('quantity', 'sum'),
    total_number_of_orders = ('transaction_id', 'count'),
    average_sales_revenue = ('revenue', 'mean')).round(2).reset_index()

# %%
spp
# Out:
#    salesperson product  total_sales_revenue  total_quantity_sold  \
# 0        David   Chair              12000.0                  8.0
# 1        David    Desk              12000.0                  4.0
# 2        David  Laptop              48000.0                  4.0
# 3        David   Phone             144000.0                 18.0
# 4        David  Tablet              54000.0                  9.0
# 5         John   Chair              22500.0                 15.0
# 6         John    Desk              18000.0                  6.0
# 7         John  Laptop              72000.0                  6.0
# 8         John   Phone             112000.0                 14.0
# 9         John  Tablet              36000.0                  6.0
# 10        Mary   Chair              18000.0                 12.0
# 11        Mary    Desk              27000.0                  9.0
# 12        Mary  Laptop              36000.0                  3.0
# 13        Mary   Phone             120000.0                 15.0
# 14        Mary  Tablet              24000.0                  4.0
# 15       Sarah   Chair              21000.0                 14.0
# 16       Sarah    Desk              18000.0                  6.0
# 17       Sarah  Laptop              24000.0                  2.0
# 18       Sarah   Phone              64000.0                  8.0
# 19       Sarah  Tablet              36000.0                  6.0
#
#     total_number_of_orders  average_sales_revenue
# 0                        2                 6000.0
# 1                        2                 6000.0
# 2                        2                24000.0
# 3                        3                48000.0
# 4                        3                18000.0
# 5                        3                 7500.0
# 6                        3                 6000.0
# 7                        3                24000.0
# 8                        2                56000.0
# 9                        2                18000.0
# 10                       2                 9000.0
# 11                       3                 9000.0
# 12                       3                12000.0
# 13                       3                40000.0
# 14                       2                12000.0
# 15                       3                 7000.0
# 16                       2                 9000.0
# 17                       2                12000.0
# 18                       2                32000.0
# 19                       3                12000.0

# %%
lg.info("Saving to salesperson_performance.csv")
lg.info("Data Cleaning and Transformation Complete")
spp.to_csv("C:/sc_LwazisileMhlambi_2026/Graduate Projects 2026 - Sales Data Processing and Business Insights System/project/output/salesperson_performance.csv", index=False)
